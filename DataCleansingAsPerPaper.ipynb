# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import csv
import numpy as np
import re

# %%
df=pd.read_csv('/content/drive/MyDrive/Data Dissertation/UncleansedCsv.csv')

# %%
len(df)
# Out:
# 132782

# %%
df = df.drop_duplicates(subset='Text')
len(df)
# Out:
# 122222

# %%
# Replace newline characters with a space
df['Text'] = df['Text'].str.replace(r'\n', ' ', regex=True)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.3/356.3 kB 12.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for emoji: filename=emoji-2.5.1-py2.py3-none-any.whl size=351210 sha256=319384884f2c128aa185bf11caf64994ee0fe5d41dbe17ce63c2c4be78f5b362
#   Stored in directory: /root/.cache/pip/wheels/51/92/44/e2ef13f803aa08711819357e6de0c5fe67b874671141413565
# Successfully built emoji
# ...

# %%
import emoji

df['Text'] = df['Text'].apply(lambda x: emoji.demojize(str(x)))

# %%
cleanedDf = pd.DataFrame(columns=('Text', 'Label'))
i=0
for text in df.values:
  cleanedText = ' '.join(re.sub("(#[A-Za-z0-9]+)|(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text[0]).split())
  cleanedDf = cleanedDf.append({"Text":cleanedText,"Label":text[1]},ignore_index=True)
  i = i+1
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-29-f90b19bc72c2>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cleanedDf = cleanedDf.append({"Text":cleanedText,"Label":text[1]},ignore_index=True)
# <ipython-input-29-f90b19bc72c2>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cleanedDf = cleanedDf.append({"Text":cleanedText,"Label":text[1]},ignore_index=True)
# <ipython-input-29-f90b19bc72c2>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cleanedDf = cleanedDf.append({"Text":cleanedText,"Label":text[1]},ignore_index=True)
# <ipython-input-29-f90b19bc72c2>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
len(cleanedDf)
# Out:
# 122219

# %%
i =0
for text in cleanedDf.values:
  print(text[0])
  i=i+1
  if(i==5):
    break
# Out:
# Just now on Tucker Carlson it was revealed that CORONAVIRUS was CREATED in Wuhan Lab and released INTENTIONALLY
# Last night on Tucker Carlson it was revealed that CORONAVIRUS was CREATED in Wuhan Lab and released INTENTIONALLY What say you
# Top story Overhyped Coronavirus Weaponized Against Trump The Rush Limbaugh Show see more
# Overhyped Coronavirus Weaponized Against Trump The Rush Limbaugh Show
# Overhyped Coronavirus Weaponized Against Trump

# %%
# Remove vía at the ending
cleanedDf['Text'] = cleanedDf['Text'].str.replace(r' vía$', '', regex=True)

# %%
# Remove via at the ending
cleanedDf['Text'] = cleanedDf['Text'].str.replace(r' via$', '', regex=True)

# %%
# Remove via at the ending
cleanedDf['Text'] = cleanedDf['Text'].str.replace(r' /via$', '', regex=True)

# %%
# Remove from at the ending
cleanedDf['Text'] = cleanedDf['Text'].str.replace(r' from$', '', regex=True)

# %%
cleanedDfNoDups.drop(cleanedDfNoDups.index, inplace=True)
cleanedDfNoDups = pd.DataFrame(columns=('Text', 'Label'))
counter = 1
for i in range(len(cleanedDf)-1):
  if "WHO and partners call for urgent investment in nurses".lower() in cleanedDf['Text'][i].lower():
    counter = counter+1
print(counter)
if counter==1:
  cleanedDfNoDups = cleanedDfNoDups.append({"Text":"WHO and partners call for urgent investment in nurses","Label":text[1]},ignore_index=True)
# Out:
# 17

# %%
cleanedDfNoDups = pd.DataFrame(columns=('Text', 'Label'))
j = 0
for text in cleanedDf.values:
  counter = 1
  print(j)
  j=j+1
  for i in range(len(cleanedDf)-1):
    if text[0].lower() in cleanedDf['Text'][i+1].lower():
      counter = counter+1
  if counter==1:
    cleanedDfNoDups = cleanedDfNoDups.append({"Text":text[0].lower(),"Label":text[1]},ignore_index=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# 31219
# 31220
# 31221
# 31222
# 31223
# 31224
# 31225
# 31226
# 31227
# 31228
# 31229
# 31230
# 31231
# 31232
# 31233
# 31234
# 31235
# 31236
# 31237
# 31238
# 31239
# 31240
# 31241
# 31242
# 31243
# 31244
# 31245
# 31246
# 31247
# 31248
# 31249
# 31250
# 31251
# 31252
# 31253
# 31254
# 31255
# 31256
# 31257
# 31258
# 31259
# 31260
# 31261
# 31262
# 31263
# 31264
# 31265
# 31266
# 31267
# 31268
# 31269
# 31270
# 31271
# 31272
# 31273
# 31274
# 31275
# 31276
# 31277
# 31278
# 31279
# 31280
# 31281
# 31282
# 31283
# 31284
# 31285
# 31286
# 31287
# 31288
# 31289
# 31290
# 31291
# 31292
# 31293
# 31294
# 31295
# 31296
# 31297
# 31298
# 31299
# 31300
# 31301
# 31302
# 31303
# 31304
# 31305
# 31306
# 31307
# 31308
# 31309
# 31310
# 31311
# 31312
# 31313
# 31314
# 31315
# 31316
# 31317
# 31318
# 31319
# 31320
# 31321
# 31322
# 31323
# 31324
# 31325
# 31326
# 31327
# 31328
# 31329
# 31330
# 31331
# 31332
# 31333
# 31334
# 31335
# 31336
# ...

# %%
for text in cleanedDfNoDups.values:
  print(text[0])

# %%
#WHO and partners call for urgent investment in nurses
len(cleanedDfNoDups)
# Out:
# 0

# %%
cleanedDf = cleanedDf.drop_duplicates(subset='Text')
len(cleanedDf)
# Out:
# 76680

# %%
cleanedDf['Label'].value_counts()
# Out:
# TRUE    74002
# FAKE     2678
# Name: Label, dtype: int64
